# %%
# Installing Keras module
#conda install -c conda-forge keras
#!pip install -r requirements.txt

# %%
# import modules
import json
from pprint import pprint
import pandas as pd
import numpy as np
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences

from matplotlib import pyplot as plt
from sklearn.decomposition import PCA
from sklearn.neighbors import DistanceMetric
from sklearn.manifold import TSNE
from sklearn.metrics.pairwise import cosine_distances
from sklearn.metrics import pairwise_distances

from sklearn.cluster import SpectralClustering 
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import StandardScaler, normalize 
from sklearn.decomposition import PCA 
from sklearn.metrics import silhouette_score 

# additional set up
# %matplotlib inline
np.set_printoptions(precision=5, suppress=True) # suppress scientific float notation

# constants and parameters
DATA_PATH = './quantnet-data/'
IMG_PATH = './'

# load data 
with open(f'{DATA_PATH}data_file_20191119.json') as f:
    data = json.load(f)
# Out:
# Using TensorFlow backend.

# %%
# create data frame
df = {'Name': np.zeros(len(data['quantlets'])), 
      'author_of_last_comm': np.zeros(len(data['quantlets'])),
      'is_debuggable': np.zeros(len(data['quantlets'])), 
      'grade': np.zeros(len(data['quantlets'])),
      'keywords': np.zeros(len(data['quantlets']))}

df = pd.DataFrame(data=df)

# %%
# extract the columns we need
counter=0
for c, i in enumerate(data['quantlets']):
    print(i)
    df.loc[c,'Name'] = i
    df.loc[c,'author_of_first_comm'] = data['quantlets'][i]['commit_first']['commit']['author']['name']
    df.loc[c,'author_of_last_comm'] = data['quantlets'][i]['commit_last']['commit']['author']['name']
    df.loc[c,'is_debuggable'] = data['quantlets'][i]['is_debuggable']
    try:
        df.loc[c,'grade'] = data['quantlets'][i]['grade']
        df.loc[c,'keywords'] = ' '.join(str(e) for e in set(data['quantlets'][i]['keyword_list']))
    except:
        df.loc[c,'grade'] = 'did not work'
        df.loc[c,'keywords'] ='did not work'
        counter+=1
print(f'Could not load {counter} quantlets.')
df = df[df['is_debuggable']==True];
# Out:
# ADM/HermPolyPlot/Metainfo.txt
# AOBDL_code/codes/metainfo.txt
# ARR/ARRboxage/Metainfo.txt
# ARR/ARRboxgscit/Metainfo.txt
# ARR/ARRboxhb/Metainfo.txt
# ARR/ARRcormer/Metainfo.txt
# ARR/ARRdenmer2d/Metainfo.txt
# ARR/ARRdenmer3d/Metainfo.txt
# ARR/ARRhexage/Metainfo.txt
# ARR/ARRhexcit/Metainfo.txt
# ARR/ARRhexhin/Metainfo.txt
# ARR/ARRhismer/Metainfo.txt
# ARR/ARRmosage/Metainfo.txt
# ARR/ARRmosagegr/Metainfo.txt
# ARR/ARRmossub/Metainfo.txt
# ARR/ARRpcpgscit/Metainfo.txt
# ARR/ARRpcphb/Metainfo.txt
# ARR/ARRpcpmer/Metainfo.txt
# ARR/ARRpcprp/Metainfo.txt
# ARR/ARRqrqqhb/Metainfo.txt
# ARR/ARRscaage/Metainfo.txt
# ARR/ARRscamer/Metainfo.txt
# Adaptive_Penalized_Macro_Factors/Metainfo.txt
# BCS-1/BCS_Kernel_nhTemp/Metainfo.txt
# BCS-1/BCS_MLRleaps/Metainfo.txt
# BCS-1/BCS_RANDU/Metainfo.txt
# BCS/BCS_ARM/MetaInfo.txt
# BCS/BCS_ArchimedeanContour/MetaInfo.txt
# BCS/BCS_BarGraphs/MetaInfo.txt
# BCS/BCS_Bincdf/MetaInfo.txt
# BCS/BCS_Binhist/MetaInfo.txt
# BCS/BCS_Binhyper/MetaInfo.txt
# BCS/BCS_Binnorm/MetaInfo.txt
# BCS/BCS_BinormalDensity/MetaInfo.txt
# BCS/BCS_Binpdf/MetaInfo.txt
# BCS/BCS_Binpois/MetaInfo.txt
# BCS/BCS_BivariateRegression/MetaInfo.txt
# BCS/BCS_Boxplot/MetaInfo.txt
# BCS/BCS_Boxplot2/MetaInfo.txt
# BCS/BCS_CAComplete/MetaInfo.txt
# BCS/BCS_CAmethods/MetaInfo.txt
# BCS/BCS_CauchyPdfCdf/MetaInfo.txt
# BCS/BCS_ChiNormApprox/MetaInfo.txt
# BCS/BCS_ChiPdf/MetaInfo.txt
# BCS/BCS_ChiPdfCdf/MetaInfo.txt
# BCS/BCS_ConditionalGrouped/MetaInfo.txt
# BCS/BCS_ConditionalGroupedDensity/MetaInfo.txt
# BCS/BCS_Conf1sidedleft/MetaInfo.txt
# BCS/BCS_Conf1sidedright/MetaInfo.txt
# BCS/BCS_Conf2sided/MetaInfo.txt
# BCS/BCS_ControlDensityEstimate/MetaInfo.txt
# BCS/BCS_CopulaInvarOutlier/MetaInfo.txt
# BCS/BCS_DefaultStackTimeSeries/MetaInfo.txt
# BCS/BCS_EdfsDAXFTSE/MetaInfo.txt
# BCS/BCS_ExpPdfCdf/MetaInfo.txt
# BCS/BCS_FAsummary/MetaInfo.txt
# BCS/BCS_FPdfCdf/MetaInfo.txt
# BCS/BCS_FourDimensional/MetaInfo.txt
# BCS/BCS_FuzzyMultiSets/MetaInfo.txt
# BCS/BCS_GaussianKernel/MetaInfo.txt
# BCS/BCS_HAC/MetaInfo.txt
# BCS/BCS_HelloWorld/MetaInfo.txt
# BCS/BCS_HistBinSizes/MetaInfo.txt
# BCS/BCS_HistogramBoxplotOption/MetaInfo.txt
# BCS/BCS_Integrand/MetaInfo.txt
# BCS/BCS_KernelDAX/MetaInfo.txt
# BCS/BCS_KernelSmoother/MetaInfo.txt
# BCS/BCS_Kernel_nhTemp/Metainfo.txt
# BCS/BCS_LDA/MetaInfo.txt
# BCS/BCS_LFG/MetaInfo.txt
# BCS/BCS_LOESS/MetaInfo.txt
# BCS/BCS_LP/MetaInfo.txt
# BCS/BCS_LeaveOneOut/MetaInfo.txt
# BCS/BCS_LightedPlots/MetaInfo.txt
# BCS/BCS_MDS/MetaInfo.txt
# BCS/BCS_MLRdiagnostic/MetaInfo.txt
# BCS/BCS_MLRleaps/MetaInfo.txt
# BCS/BCS_MSE/MetaInfo.txt
# BCS/BCS_Multimodal/MetaInfo.txt
# BCS/BCS_NLP/MetaInfo.txt
# BCS/BCS_NPCAbiplot/MetaInfo.txt
# BCS/BCS_Newton/MetaInfo.txt
# BCS/BCS_NonparametricRegressions/MetaInfo.txt
# BCS/BCS_NormPdfCdf/MetaInfo.txt
# BCS/BCS_NormalCopula/MetaInfo.txt
# BCS/BCS_NormalCopulaContour/MetaInfo.txt
# BCS/BCS_NormalDensityFit/MetaInfo.txt
# BCS/BCS_NormalProbability/MetaInfo.txt
# BCS/BCS_PCAbiplot/MetaInfo.txt
# BCS/BCS_PCAvar/MetaInfo.txt
# BCS/BCS_Poispdf/MetaInfo.txt
# BCS/BCS_PopularKernels/MetaInfo.txt
# BCS/BCS_RANDU/MetaInfo.txt
# BCS/BCS_RegressionCurve/MetaInfo.txt
# BCS/BCS_Rosenbrock/MetaInfo.txt
# BCS/BCS_SamplesDiagram/MetaInfo.txt
# BCS/BCS_SceneSelection/MetaInfo.txt
# BCS/BCS_SetupFile/MetaInfo.txt
# BCS/BCS_Shapes/MetaInfo.txt
# BCS/BCS_Splines/MetaInfo.txt
# BCS/BCS_StablePdfCdf/MetaInfo.txt
# BCS/BCS_StablePdfCdfSpecial/MetaInfo.txt
# BCS/BCS_SurfaceShape/MetaInfo.txt
# BCS/BCS_TwoConditioningVariables/MetaInfo.txt
# BCS/BCS_UniformKernel/MetaInfo.txt
# BCS/BCS_UnivariateRegression/MetaInfo.txt
# BCS/BCS_claytonMC/MetaInfo.txt
# BCS/BCS_ecdf/MetaInfo.txt
# BCS/BCS_hist1/MetaInfo.txt
# BCS/BCS_hist2/MetaInfo.txt
# BCS/BCS_isoMDS/MetaInfo.txt
# BCS/BCS_kNN/MetaInfo.txt
# BCS/BCS_linreg/MetaInfo.txt
# BCS/BCS_pie/MetaInfo.txt
# BCS/BCS_rp.tkrplot/MetaInfo.txt
# BCS/BCS_tPdfCdf/MetaInfo.txt
# BCS/BCS_tQQplots/MetaInfo.txt
# BERT/metainfo.txt
# BLEM/BLEMdataGlimpse/Metainfo.txt
# BLEM/BLEMdescStatEnergyData/Metainfo.txt
# BLEM/BLEMevaluateEnergyPreds/Metainfo.txt
# BLEM/BLEMevaluateMarketSim/Metainfo.txt
# BLEM/BLEMmarketSimulation/Metainfo.txt
# BLEM/BLEMplotEnergyData/Metainfo.txt
# BLEM/BLEMplotEnergyPreds/Metainfo.txt
# BLEM/BLEMplotPredErrors/Metainfo.txt
# BLEM/BLEMplotScaling/Metainfo.txt
# BLEM/BLEMpredictLASSO/Metainfo.txt
# BLEM/BLEMpredictLSTM/Metainfo.txt
# BLEM/BLEMpredictNaive/Metainfo.txt
# BLEM/BLEMtuneLSTM/Metainfo.txt
# Balanced_Quantile_Predictive_Regression/BQPR_backtesting/Metainfo.txt
# Balanced_Quantile_Predictive_Regression/BQPR_betadensity/Metainfo.txt
# Balanced_Quantile_Predictive_Regression/BQPR_power/Metainfo.txt
# Balanced_Quantile_Predictive_Regression/BQPR_predictability/Metainfo.txt
# Balanced_Quantile_Predictive_Regression/BQPR_size/Metainfo.txt
# Balanced_Quantile_Predictive_Regression/BQPR_statdensity/Metainfo.txt
# BetaBoost/Metainfo.txt
# CCID/CCIDCandles/Metainfo.txt
# CCID/CCIDHistRet/Metainfo.txt
# CCID/CCIDHistReturnsDensity/Metainfo.txt
# CCID/CCIDHistVola/Metainfo.txt
# CCID/CCIDReturns/Metainfo.txt
# CCID/CCIDcorr/Metainfo.txt
# CCID/CCIDvolaGAM/Metainfo.txt
# CCID/CCIDvolumeGAM/Metainfo.txt
# CCNMGQR/Conditional_stochastic_dominance/Metainfo.txt
# CCNMGQR/Simu1_Theoretical_cov_error_er_hetero/Metainfo.txt
# CCNMGQR/Simu2_Theoretical_cov_error_er_hom/Metainfo.txt
# CCNMGQR/Simu3_Theoretical_cov_error_qr_hetero/Metainfo.txt
# CCNMGQR/Simu4_Theoretical_cov_error_qr_hom/Metainfo.txt
# CCNMGQR/Simu5_Bootstrap_cov_error_er_hetero/Metainfo.txt
# CCNMGQR/Simu6_Bootstrap_cov_error_er_hom/Metainfo.txt
# CCNMGQR/Simu7_Bootstrap_cov_error_qr_hetero/Metainfo.txt
# CCNMGQR/Simu8_Bootstrap_cov_error_qr_hom/Metainfo.txt
# CCP/CCPBootstrap/Metainfo.txt
# CCP/CCPConstruction/Metainfo.txt
# CCP/CCPDescriptivestat/Metainfo.txt
# CCP/CCPDiversification/Metainfo.txt
# CCP/CCPEfficient_surface/Metainfo.txt
# CCP/CCPHistReturnsDensity/Metainfo.txt
# CCP/CCPPerformance/Metainfo.txt
# CCP/CCPRisk_contribution/Metainfo.txt
# CCP/CCPTests/Metainfo.txt
# CCP/CCPWeights/Metainfo.txt
# CCS/CCSAlphas/Metainfo.txt
# CCS/CCSCryptoSurvival/Metainfo.txt
# CCS/CCSHistMarketCap/Metainfo.txt
# CCS/CCSHistMarketCapHighValAreas/Metainfo.txt
# CCS/CCSHistReturnsDensity/Metainfo.txt
# CCS/CCSMarketCapvsVol/Metainfo.txt
# CCS/CCSMeansRollingWindow/Metainfo.txt
# CCS/CCSPCAExVar/Metainfo.txt
# CCS/CCSSdRollingWindow/Metainfo.txt
# CCS/CCSecdf/Metainfo.txt
# CGBRP/CGBRP_Arbitrage_Free_NS_Model/Metainfo.txt
# CGBRP/CGBRP_Risk_Premia_Network/Metainfo.txt
# CMB/CMBbubbles/Metainfo.txt
# CMB/CMBbubblesbuilder/Metainfo.txt
# CMB/CMBcpureg/Metainfo.txt
# CMB/CMBcpuregp/Metainfo.txt
# CMB/CMBcpuscrap/Metainfo.txt
# CMB/CMBhddreg/Metainfo.txt
# CMB/CMBhddregp/Metainfo.txt
# CMB/CMBhddscrap/Metainfo.txt
# COP-Estimation-Misspec/COPSimStuPercRelBiasLarge/Metainfo.txt
# COP-Estimation-Misspec/COPSimStuPercRelBiasMix/Metainfo.txt
# COP-Estimation-Misspec/COPSimStudyBoxpl/Metainfo.txt
# COP-Estimation-Misspec/COPSimStudyResLarge/Metainfo.txt
# COP-Estimation-Misspec/COPSimStudyResMix/Metainfo.txt
# COP-Estimation-Misspec/COPapp2residual/Metainfo.txt
# COP-Estimation-Misspec/COPmisspecClayGum/Metainfo.txt
# COP-Estimation-Misspec/COPp.values/Metainfo.txt
# COP-Estimation-Misspec/COPretaparch/Metainfo.txt
# COP-Estimation-Misspec/COPtautotheta/Metainfo.txt
# COP-Estimation-Misspec/COPthetasDiff/Metainfo.txt
# COP-Estimation-Misspec/CopDynEst/Metainfo.txt
# COP-Estimation-Misspec/CopVaRBackTesRes1/Metainfo.txt
# CRIXdeeplearning/CRIXbtcBB/Metainfo.txt
# CRIXdeeplearning/CRIXportfolio/Metainfo.txt
# CRIXdeeplearning/CRIXrnn/Metainfo.txt
# CSC/Datasets/Metainfo.txt
# CSC/Transformations/Metainfo.txt
# Clustering_Validation_Pipeline/YAMLcentroids/Metainfo.txt
# Clustering_Validation_Pipeline/YAMLcleanmerge/Metainfo.txt
# Clustering_Validation_Pipeline/YAMLnumbchars/Metainfo.txt
# Clustering_Validation_Pipeline/lsa_determineSign/Metainfo.txt
# Clustering_Validation_Pipeline/lsa_heatmaperr/Metainfo.txt
# Clustering_Validation_Pipeline/lsa_heatmapsvd/Metainfo.txt
# CoVaR/Centrality/metainfo.txt
# CoVaR/ConfidenceBand/metainfo.txt
# CoVaR/QuantileLasso/metainfo.txt
# CoVaR/VaR_forecast_backtesting/metainfo.txt
# Collaboration_Example_MVAghadatail/Metainfo.txt
# Collaboration_Example_MVAghdis/Metainfo.txt
# Collaboration_Example_MVAlaplacedis/Metainfo.txt
# Copula/Metainfo.txt
# CrixToDate/CTD_CRIX_Correlations/metainfo.txt
# CrixToDate/CTD_CRIX_Full_24h/24h/metainfo.txt
# CrixToDate/CTD_CRIX_Full_24h/Full/metainfo.txt
# CrixToDate/CTD_Garch/metainfo.txt
# CrixToDate/CTD_Volatility/CC_Vola/metainfo.txt
# CrixToDate/CTD_Volatility/CRIX_Vola/metainfo.txt
# CrixToDate/Networks/metainfo.txt
# CrixToDate/SHA256/metainfo.txt
# CryptoDynamics/CryptoDynamics_Estimation/metainfo.txt
# CryptoDynamics/CryptoDynamics_Scraping/metainfo.txt
# CryptoDynamics/CryptoDynamics_Series/metainfo.txt
# CryptoDynamics/CryptoDynamics_Wachter/metainfo.txt
# DAIIkmeansEM/Metainfo.txt
# DCA_comparison/Cluster_sizes/Metainfo.txt
# DCA_comparison/Clustering_Evaluation/Metainfo.txt
# DCA_comparison/Hierarchical_Clustering_in_R/Metainfo.txt
# DCA_comparison/Sum_of_squares/Metainfo.txt
# DCA_comparison/k-means-algorithms/Metainfo.txt
# DCA_comparison/manual_k-means_centroids/Metainfo.txt
# DDINetwork/DDINetwork_CDS/metainfo.txt
# DDINetwork/DDINetwork_CDS_forecast/metainfo.txt
# DDINetwork/DDINetwork_network_US_EU/metainfo.txt
# DDINetwork/DDINetwork_network_dynamic/metainfo.txt
# DDINetwork/DDINetwork_network_static/metainfo.txt
# DEDA-Bitcoin/Bitcoin_Evaluation/Metainfo.txt
# DEDA-Bitcoin/Bitcoin_Simulation/Metainfo.txt
# DEDA_Class_2017/DEDA_Class_2017_Condition&Iteration/Metainfo.txt
# DEDA_Class_2017/DEDA_Class_2017_InputOutput/Metainfo.txt
# DEDA_Class_2017/DEDA_Class_2017_MachineLearning/Metainfo.txt
# DEDA_Class_2017/DEDA_Class_2017_Python_Introduction/Metainfo.txt
# DEDA_Class_2017/DEDA_Class_2017_Statistics&Finance/Metainfo.txt
# DEDA_Class_2017/DEDA_Class_2017_WebScrapingIntro/Metainfo.txt
o.txt
# DEDA_Class_2019SS/DEDA_Class_2019SS_Crypto_News_Sentiment/DEDA_Class_2019SS_Crypto_News_Sentiment_Scraping_Tool/metainfo.txt
# DEDA_Class_2019SS/DEDA_Class_2019SS_Crypto_News_Sentiment/DEDA_Class_2019SS_Crypto_News_Sentiment_Sentiment_Scoring/metainfo.txt
# DEDA_Class_SS2018/DEDA_Class_SS2018_CCT/Metainfo.txt
# DEDA_Class_SS2018/DEDA_Class_SS2018_DictionaryForTurkishSentiment/Metainfo.txt
# DEDA_Class_SS2018/DEDA_Class_SS2018_IRTG_Guest_Matching/TextAnalytics/Metainfo.txt
# DEDA_Class_SS2018/DEDA_Class_SS2018_IRTG_Guest_Matching/WebScraping/Metainfo.txt
# DEDA_Class_SS2018/DEDA_Class_SS2018_Per_Bay_Crypto_Mining_Pool/Metainfo.txt
# DEDA_Class_SS2018/DEDA_Class_SS2018_Reddit_Sentiment/metainfo.txt
# DEDA_Class_SS2018/DEDA_Class_SS2018_Regulation Risk for Cryptocurrencies/Metainfo.txt
# DEDA_Class_SS2018/DEDA_Class_SS2018_Route Optimisation & Site Selection/ACO_RouteOptimisation/Metainfo.txt
# DEDA_Class_SS2018/DEDA_Class_SS2018_Route Optimisation & Site Selection/Folium_SiteSelection/Metainfo.txt
# DEDA_Class_SS2018/DEDA_Class_SS2018_ScammerDetection/WebApp/Metainfo.txt
# DEDA_Class_SS2018/DEDA_Class_SS2018_ScammerDetection/outdated_scraper/Metainfo.txt
# DEDA_Class_SS2018/DEDA_Class_SS2018_Stock_News_Sentiment/Metainfo.txt
# DEDA_Class_SS2018/DEDA_Class_SS2018_Sucess_of_startups-master/Metainfo.txt
# DEDA_Class_SS2018/DEDA_Class_SS2018_WorldCupPredictions/WorldCupPredictions/Metainfo.txt
# DEDA_Class_SS2018/DEDA_Class_SS2018_WorldCupPredictions/WorldMaps/Metainfo.txt
# DEDA_RandForest/DEDA_RandForest/Metainfo.txt
# DEDA_RandForest/DEDA_RandForest_GermanCredit/Metainfo.txt
# DEDA_SVM/DEDA_SVM_Linear/metainfo.txt
# DEDA_SVM/DEDA_SVM_Nonlinear/metainfo.txt
# DEDA_SVM/DEDA_SVM_P2P/metainfo.txt
# DEDA_SVM/DEDA_SVM_Spiral/metainfo.txt
# DEDA_SVM/DEDA_SVM_Swiss/metainfo.txt
# DEDA_SVM/DEDA_SVM_Swiss_PC/metainfo.txt
# DEDA_class2019_SYSU/DEDA_class2019_SYSU_Abstract_LDA_Crawler/metainfo.txt
# DEDA_class2019_SYSU/DEDA_class2019_SYSU_Abstract_LDA_LDAAnalysis/metainfo.txt
# DEDA_class2019_SYSU/DEDA_class2019_SYSU_Abstract_LDA_wordcloud/metainfo.txt
# DEDA_class2019_SYSU/DEDA_class2019_SYSU_DrawPeppaPig/metainfo.txt
# DEDA_class2019_SYSU/DEDA_class2019_SYSU_LSTMPrediction/metainfo.txt
# DMF/DMFchord/Metainfo.txt
# DMF/DMFpubProPubVol/Metainfo.txt
# DMF/DMFsankey/Metainfo.txt
# DMF/DMFtsmtpe/Metainfo.txt
# DR_GATES/Correlation_Plot/Metainfo.txt
# DR_GATES/Sim_Replication_TM_DR/Metainfo.txt
# DT_AlphaShape/A-Shape_CRIX_VCRIX/Metainfo.txt
# DT_AlphaShape/A-Shape_Crystal/Metainfo.txt
# DT_AlphaShape/TS_CRIX_VCRIX/Metainfo.txt
# DYTEC/P_beta_est/Metainfo.txt
# DYTEC/chp_test/Metainfo.txt
# DYTEC/data_load_hurricanes/Metainfo.txt
# DYTEC/tau_variance/Metainfo.txt
# Data-adaptive-PCA/DPCA_example/Metainfo.txt
# Data-adaptive-PCA/DPCA_source_code/Metainfo.txt
# DataGenerationForCausalInference/Metainfo.txt
# DeepLearning/ANNregression/Metainfo.txt
# DeepLearning/ActivationFunction/Metainfo.txt
# DeepLearning/mnistDeepLearning/Metainfo.txt
# DigitalEconomyDecisionAnalytics/DEDA_ConditionIteration/Metainfo.txt
# DigitalEconomyDecisionAnalytics/DEDA_InputOutput/Metainfo.txt
# DigitalEconomyDecisionAnalytics/DEDA_Introduction/Metainfo.txt
# DigitalEconomyDecisionAnalytics/DEDA_MachineLearning/Metainfo.txt
# DigitalEconomyDecisionAnalytics/DEDA_StatisticsFinance/Metainfo.txt
# DigitalEconomyDecisionAnalytics/DEDA_WebScrapingIntro/Metainfo.txt
# Disaster/adaptive_algorithm_1/Metainfo.txt
# DistributionalForecasts.jl/Metainfo.txt
# Dynamics-of-Tail-Event-Curves/DYTEC_hurricanes/Metainfo.txt
# Dynamics-of-Tail-Event-Curves/DYTEC_simulation_all/Metainfo.txt
# Dynamics-of-Tail-Event-Curves/DYTEC_temperature/Metainfo.txt
# EIV_UCS/EIV_UCS/Metainfo.txt
# EMAIS/EMAIS_DataManip/Metainfo.txt
# EMAIS/EMAIS_Optim/Metainfo.txt
# EMAIS/EMAIS_ParamEst/Metainfo.txt
# EMAIS/EMAIS_Visual/Metainfo.txt
# EconCrix/econ-tgarch/Metainfo.txt
# EconCrix/econ_arch/Metainfo.txt
# EconCrix/econ_arima/Metainfo.txt
# EconCrix/econ_ccgar/Metainfo.txt
# EconCrix/econ_crix/Metainfo.txt
# EconCrix/econ_garch/Metainfo.txt
# EconCrix/econ_vola/Metainfo.txt
# FASTEC-with-Expectiles/Expectile_RSC/Metainfo.txt
# FASTEC-with-Expectiles/FASTECChinaTemper2008/Metainfo.txt
# FASTEC-with-Expectiles/FASTECSAMCVaR/Metainfo.txt
# FASTEC-with-Expectiles/FASTEC_with_Expectiles/Metainfo.txt
# FCVAR/ACF_plot/metainfo.txt
# FCVAR/FCVAR_para_est/metainfo.txt
# FCVAR/Integration_order_est/metainfo.txt
# FPCA/FPCAcomponents/Metainfo.txt
# FPCA/FPCAepan/Metainfo.txt
# FPCA/FPCAexpiration/Metainfo.txt
# FPCA/FPCAgpu/Metainfo.txt
# FPCA/FPCAindividual/Metainfo.txt
# FPCA/FPCAloadings/Metainfo.txt
# FPCA/FPCAmultiloc/Metainfo.txt
# FPCA/FPCAreal_data/Metainfo.txt
# FPCA/FPCAsimulate_input/Metainfo.txt
# FPCA/FPCAsimulation/Metainfo.txt
# FPCA/FPCAvariance/Metainfo.txt
# FPCA_Electricity/FPCA_Electricity_Application/Metainfo.txt
# FPCA_Electricity/FPCA_Electricity_Simulation/Metainfo.txt
# FPCA_Electricity/FPCA_Electricity_Surface/Metainfo.txt
# FRM/FRM_GT/Metainfo.txt
# FRM/FRM_SRISK/Metainfo.txt
# FRM/FRM_VIX/Metainfo.txt
# FRM/FRM_compare_nf/Metainfo.txt
# FRM/FRM_compare_of/Metainfo.txt
# FRM/FRM_compare_ws/Metainfo.txt
# FRM/FRM_download_data/Metainfo.txt
# FRM/FRM_lambda_series/Metainfo.txt
# FRM/FRM_parallel_compute/Metainfo.txt
# FRM/FRM_per_cap/Metainfo.txt
# FVC/FVCConvNet/metainfo.txt
# FVC/FVCEurostoxxLDA/metainfo.txt
# FVC/FVCEurostoxxOLS/metainfo.txt
# FVC/FVCEurostoxxPLS/metainfo.txt
# FVC/FVCbarplot/metainfo.txt
# FVC/FVCcall_API/metainfo.txt
# FVC/FVCconf_API/metainfo.txt
# FVC/FVCconf_CNN/metainfo.txt
# FVC/FVCconf_finetune/metainfo.txt
# FVC/FVCcorr/metainfo.txt
# FVC/FVCcorrcircle/metainfo.txt
# FVC/FVCemo_vs_stock/metainfo.txt
# FVC/FVCfinetuning/metainfo.txt
# FVC/FVCheatmap/metainfo.txt
# FVC/FVCload_dataset/metainfo.txt
# FVC/FVCperformance/metainfo.txt
# FVC/FVCpressdays/metainfo.txt
# Face-Recognition/FaceRecognition_FLDA/MetaInfo.txt
# Face-Recognition/FaceRecognition_PCA/MetaInfo.txt
# Face-Recognition/FaceRecognition_SVM/MetaInfo.txt
# Face-Recognition/FaceRecognition_kNN/MetaInfo.txt
# Factor_copula_systemic/FCOP_network_plots/Metainfo.txt
# FittingElephant/Metainfo.txt
# GMMcluster/metainfo.txt
# GMMvb/metainfo.txt
# GPLM/GPLM_example1_H0_fixed_design/Metainfo.txt
# GPLM/GPLM_example1_H0_random_design/Metainfo.txt
# GPLM/GPLM_example1_H1/Metainfo.txt
# GPLM/GPLM_example2_wood/Metainfo.txt
# GPLM/GPLM_example3_non-orthogonal/Metainfo.txt
# GPLM/GPLM_example3_orthogonal/Metainfo.txt
# GPLM/GPLM_example4_non-orthogonal/Metainfo.txt
# GPLM/GPLM_example4_orthogonal/Metainfo.txt
# GPLM/GPLM_example5_poisson_non-orthogonal/Metainfo.txt
# GPLM/GPLM_example5_poisson_orthogonal/Metainfo.txt
# Genus_proximum_cryptos/CONV_cryptos/Metainfo.txt
# Genus_proximum_cryptos/Cluster_cryptos/Metainfo.txt
# Genus_proximum_cryptos/DFA_cryptos/Metainfo.txt
# Genus_proximum_cryptos/FA_cryptos/Metainfo.txt
# Genus_proximum_cryptos/Mkt_cryptos/Metainfo.txt
# Genus_proximum_cryptos/SFA_Cryptos/Metainfo.txt
# Genus_proximum_cryptos/VCS_cryptos/Metainfo.txt
# GeoCopula/geocopula_emp/Metainfo.txt
# GeoCopula/geocopula_est/Metainfo.txt
# GeoCopula/geocopula_par/Metainfo.txt
# GrangerCausalityTestInQuantile/Metainfo.txt
# HARRV/futuresPriceSimulation/Metainfo.txt
# HClustering/DEDA_HClustering_image_example_km/metainfo.txt
# HClustering/DEDA_HClustering_quantlets/metainfo.txt
# HClustering/DEDA_HClustering_tSNE_vs_PCA/metainfo.txt
# HFHD/hfhd_cirnet/Metainfo.txt
# HFHD/hfhd_dataclean/Metainfo.txt
# HFHD/hfhd_marketimpact/Metainfo.txt
# HFHD/hfhd_marketimpact_diff/Metainfo.txt
# HFHD/hfhd_risktran/Metainfo.txt
# HFHD/hfhd_rob/Metainfo.txt
# HFHD/hfhd_tvnet/Metainfo.txt
# Hedge/Metainfo.txt
# HedgingCRIX/Metainfo.txt
# IC/ICplots/Metainfo.txt
# ICA/metainfo.txt
# INET/INET-RMSE/Metainfo.txt
# INET/INET-cluster/Metainfo.txt
# INET/INET-connectedness/Metainfo.txt
# INET/INET-eigcentr/Metainfo.txt
# INET/INET-nettrading/Metainfo.txt
# INET/INET-portret/Metainfo.txt
# INET/INET-qlasso/Metainfo.txt
# INET/INET-qqplot/Metainfo.txt
# INET/INET-regression/Metainfo.txt
# INET/INET-rollingdire/Metainfo.txt
# INET/INET-totaldire/Metainfo.txt
# INET/INET-totalnet/Metainfo.txt
# Improving_Crime_Counts/census_data_cleaning/metainfo.txt
# Improving_Crime_Counts/crime_data_cleaning/metainfo.txt
# Improving_Crime_Counts/estimation_and_prediction_property_crime/metainfo.txt
# Improving_Crime_Counts/estimation_and_prediction_violent_crime/metainfo.txt
# Improving_Crime_Counts/evaluate_predictions/metainfo.txt
# Improving_Crime_Counts/feature_combination_selection/metainfo.txt
# Improving_Crime_Counts/foursquare_data_cleaning/metainfo.txt
# Improving_Crime_Counts/plotting_census_variables/metainfo.txt
# Improving_Crime_Counts/plotting_property_crime/metainfo.txt
# Improving_Crime_Counts/plotting_taxi_flow/metainfo.txt
# Improving_Crime_Counts/plotting_violent_crime/metainfo.txt
# Improving_Crime_Counts/twitter_data_cleaning/metainfo.txt
# Kelly/Kelly_Bernoulli/Metainfo.txt
# Kelly/Kelly_Bernoulli_GUI/Metainfo.txt
# Kelly/Kelly_Gaussian/Metainfo.txt
# Kelly/Stable_Kelly_LogDensityFinancials/Metainfo.txt
# Kelly/Stable_Kelly_MomentDistribution/Metainfo.txt
# Kelly/Stable_Kelly_MomentIncrease/Metainfo.txt
# Kelly/Stable_Kelly_Rescaling/Metainfo.txt
# LASSO_Time_Space/LTS_inference/Metainfo.txt
# LASSO_Time_Space/LTS_lambda_dep/Metainfo.txt
# LASSO_Time_Space/LTS_lambda_iid/Metainfo.txt
# LDA-DTM/LDA-DTM_Christmas_Song/Metainfo.txt
# LDA-DTM/LDA-DTM_Regulation_Risk/Metainfo.txt
# LDA-DTM/LDA-DTM_Shakespeare/Metainfo.txt
# LDA-DTM/LDA-DTM_Speech_XiJinping/Metainfo.txt
# LDA-DTM/LDA-DTM_dirichlet_simulation/Metainfo.txt
# LDA-DTM/LDA-DTM_nasdaq/Metainfo.txt
# LDA_thesis/metainfo.txt
# LETF-Moneyness/LETFConfBands05SDS/Metainfo.txt
# LETF-Moneyness/LETFConfBands05SPY/Metainfo.txt
# LETF-Moneyness/LETFConfBands05SSO/Metainfo.txt
# LETF-Moneyness/LETFConfBands05UPRO/Metainfo.txt
# LETF-Moneyness/LETFConfBands06SDS/Metainfo.txt
# LETF-Moneyness/LETFConfBands06SPY/Metainfo.txt
# LETF-Moneyness/LETFConfBands06SSO/Metainfo.txt
# LETF-Moneyness/LETFConfBands06UPRO/Metainfo.txt
# LETF-Moneyness/LETFConfBands07SDS/Metainfo.txt
# LETF-Moneyness/LETFConfBands07SPY/Metainfo.txt
# LETF-Moneyness/LETFConfBands07SSO/Metainfo.txt
# LETF-Moneyness/LETFConfBands07UPRO/Metainfo.txt
# LETF-Moneyness/LETFFactorFuncs/Metainfo.txt
# LETF-Moneyness/LETFIV/Metainfo.txt
# LETF-Moneyness/LETFIVMonSc/Metainfo.txt
# LETF-Moneyness/LETFIVSurfPlot/Metainfo.txt
# LETF-Moneyness/LETFIVTrueMonsc/Metainfo.txt
# LETF-Moneyness/LETFRMSPE/Metainfo.txt
# LETF-Moneyness/LETFStochLoads/Metainfo.txt
# LIBRO/LIBRObox1/Metainfo.txt
# LIBRO/LIBRObox2/Metainfo.txt
# LIBRO/LIBROreturn/Metainfo.txt
# LIBRO/LIBROscatter/Metainfo.txt
# LIBRO/LIBROsd_no_shortsell/Metainfo.txt
# LIBRO/LIBROweight/Metainfo.txt
# LIBRO/LIBROweight_no_shortsell/Metainfo.txt
# LMVCAViaR/LMVCAViaR_adaptive_estimation_001/metainfo.txt
# LMVCAViaR/LMVCAViaR_adaptive_estimation_005/metainfo.txt
# LMVCAViaR/LMVCAViaR_adaptive_estimation_length/metainfo.txt
# LMVCAViaR/LMVCAViaR_adaptive_quantile/metainfo.txt
# LMVCAViaR/LMVCAViaR_estimate_rolling/metainfo.txt
# LMVCAViaR/LMVCAViaR_return_plot/metainfo.txt
# Local_Quantile_Regression/LAWS/Metainfo.txt
# Local_Quantile_Regression/LFrobust/Metainfo.txt
# Local_Quantile_Regression/LQR_expectilecurves/Metainfo.txt
# Local_Quantile_Regression/LQRcheck/Metainfo.txt
# MCAR/MCARtest/Metainfo.txt
# METISNET/METISNET_NNQR_centrality/metainfo.txt
# METISNET/METISNET_NNQR_dyn_centrality/metainfo.txt
# METISNET/METISNET_adjtonet/Metainfo.txt
# METISNET/METISNET_centralitycomparison/Metainfo.txt
# METISNET/METISNET_centralitymeasures/Metainfo.txt
# METIS_Jump_Processes/LeeMyklandJumpTest/metainfo.txt
# MHE/MHEEnsembleEvaluation/Metainfo.txt
# MHE/MHEMetaheuristicEnsembles/Metainfo.txt
# MHE/MHEModelClassifiers/Metainfo.txt
# MLvsGARCH/MLvsGARCHcomp/Metainfo.txt
# MLvsGARCH/MLvsGARCHecon/Metainfo.txt
# MLvsGARCH/MLvsGARCHml/Metainfo.txt
# MMSTAT/MMSTATconfi_mean_len/Metainfo.txt
# MMSTAT/MMSTATconfi_pi/Metainfo.txt
# MMSTAT/MMSTATconfi_two_means/Metainfo.txt
# MMSTAT/MMSTATcorrelation/Metainfo.txt
# MMSTAT/MMSTATcrosstable/Metainfo.txt
# MMSTAT/MMSTATdice_game/Metainfo.txt
# MMSTAT/MMSTATdistribution_binom/Metainfo.txt
# MMSTAT/MMSTATdistribution_exponential/Metainfo.txt
# MMSTAT/MMSTATdistribution_hyper/Metainfo.txt
# MMSTAT/MMSTATdistribution_normal/Metainfo.txt
# MMSTAT/MMSTATdistribution_poisson/Metainfo.txt
# MMSTAT/MMSTATdotplot_location/Metainfo.txt
# MMSTAT/MMSTATdotplot_parameter/Metainfo.txt
# MMSTAT/MMSTAThistogram_simple/Metainfo.txt
# MMSTAT/MMSTATmonty_hall/Metainfo.txt
# MMSTAT/MMSTATrank_correlation/Metainfo.txt
# MMSTAT/MMSTATsample_param/Metainfo.txt
# MVA-ToDo/QID-932-MVAMDSnonmstart/Metainfo.txt
# MVA-ToDo/QID-933-MVAMDSpooladj/Metainfo.txt
# MVA-ToDo/QID-934-MVAnmdscar1/Metainfo.txt
# MVA-ToDo/QID-935-MVAnmdscar2/Metainfo.txt
# MVA-ToDo/QID-936-MVAnmdscar3/Metainfo.txt
# MVA-ToDo/QID-941-MVAprofil/Metainfo.txt
# MVA-ToDo/QID-942-MVAdenbank2/Metainfo.txt
# MVA-ToDo/QID-945-MVApcabank/Metainfo.txt
# MVA-ToDo/QID-948-MVApcabankr/Metainfo.txt
# MVA-ToDo/QID-949-MVAnpcausco2i/Metainfo.txt
# MVA-ToDo/QID-986-MVAnpcatime/Metainfo.txt
# MVA-ToDo/QID-XXXX-MVAspecclustspiral/Metainfo.txt
# MVA/QID-1046-MVAdrug/Metainfo.txt
# MVA/QID-1048-MVAcpcaiv/Metainfo.txt
# MVA/QID-1072-MVAcorrjourn/Metainfo.txt
# MVA/QID-1073-MVAcorrcrime/Metainfo.txt
# MVA/QID-1113-MVAcorrbac/Metainfo.txt
# MVA/QID-1114-MVAdecofood/Metainfo.txt
# MVA/QID-1115-MVAnpcausco/Metainfo.txt
# MVA/QID-1116-MVAnpcausco2/Metainfo.txt
# MVA/QID-1117-MVAnpcahous/Metainfo.txt
# MVA/QID-1118-MVAnpcahousi/Metainfo.txt
# MVA/QID-1195-MVAageCom/Metainfo.txt
# MVA/QID-1196-MVAageIncome/Metainfo.txt
# MVA/QID-1198-MVAcanus/Metainfo.txt
# MVA/QID-1199-MVAcltbern/Metainfo.txt
# MVA/QID-1200-MVAcltbern2/Metainfo.txt
# MVA/QID-1201-MVAclus8p/Metainfo.txt
# MVA/QID-1202-MVAclusbank/Metainfo.txt
# MVA/QID-1204-MVAclusbh/Metainfo.txt
# MVA/QID-1205-MVAclusfood/Metainfo.txt
# MVA/QID-1206-MVAcontbank2/Metainfo.txt
# MVA/QID-1207-MVAdenbank3/Metainfo.txt
# MVA/QID-1208-MVAdiscbh/Metainfo.txt
# MVA/QID-1209-MVAdisnorm/Metainfo.txt
# MVA/QID-1211-MVAfacthous/Metainfo.txt
# MVA/QID-1212-MVAghcontour/Metainfo.txt
# MVA/QID-1213-MVAincomeLi/Metainfo.txt
# MVA/QID-1214-MVAmdscarm/Metainfo.txt
# MVA/QID-1215-MVAnpcabank/Metainfo.txt
# MVA/QID-1216-MVAnpcabanki/Metainfo.txt
# MVA/QID-1223-MVApcabanki/Metainfo.txt
# MVA/QID-1225-MVApcasimu/Metainfo.txt
# MVA/QID-1226-MVAportfol/Metainfo.txt
# MVA/QID-1227-MVAportfol_IBM_Ford/Metainfo.txt
# MVA/QID-1229-MVAreturns/Metainfo.txt
# MVA/QID-1230-MVAsample1000/Metainfo.txt
# MVA/QID-1233-MVAsir2data/Metainfo.txt
# MVA/QID-1234-MVAsirdata/Metainfo.txt
# MVA/QID-1235-MVAtdis/Metainfo.txt
# MVA/QID-1264-MVAcauchy/Metainfo.txt
# MVA/QID-1265-MVAcorrCar/Metainfo.txt
# MVA/QID-1266-MVAcorrEyeHair/Metainfo.txt
# MVA/QID-1267-MVAgausscauchy/Metainfo.txt
# MVA/QID-1268-MVAsimdep1/Metainfo.txt
# MVA/QID-1477-MVAghadatail/Metainfo.txt
# MVA/QID-1478-MVAghdis/Metainfo.txt
# MVA/QID-1479-MVAghdistail/Metainfo.txt
# MVA/QID-1480-MVAghsurface/Metainfo.txt
# MVA/QID-1481-MVAlaplacedis/Metainfo.txt
# MVA/QID-1482-MVAtdistail/Metainfo.txt
# MVA/QID-1484-MVAboxbank6/Metainfo.txt
# MVA/QID-1485-MVAboxcar/Metainfo.txt
# MVA/QID-1486-MVAboxcity/Metainfo.txt
# MVA/QID-1487-MVAhexaAl/Metainfo.txt
# MVA/QID-1489-MVAhisbank1/Metainfo.txt
# MVA/QID-1490-MVAhisbank2/Metainfo.txt
# MVA/QID-1491-MVAdraftbank4/Metainfo.txt
# MVA/QID-1492-MVAmixture/Metainfo.txt
# MVA/QID-1493-MVAdenbank/Metainfo.txt
# MVA/QID-1528-MVAashbank/Metainfo.txt
# MVA/QID-1529-MVAscabank45/Metainfo.txt
# MVA/QID-1530-MVAscabank56/Metainfo.txt
# MVA/QID-1531-MVAscabank456/Metainfo.txt
# MVA/QID-1532-MVAcareffect/Metainfo.txt
# MVA/QID-1569-MVAandcur2/Metainfo.txt
# MVA/QID-1570-MVAparcoo1/Metainfo.txt
# MVA/QID-1571-MVAparcoo2/Metainfo.txt
# MVA/QID-1572-MVApcp1/Metainfo.txt
# MVA/QID-1573-MVApcp2/Metainfo.txt
# MVA/QID-1574-MVApcp3/Metainfo.txt
# MVA/QID-1575-MVApcp4/Metainfo.txt
# MVA/QID-1576-MVApcp5/Metainfo.txt
# MVA/QID-1577-MVApcp6/Metainfo.txt
# MVA/QID-1578-MVApcp7/Metainfo.txt
# MVA/QID-1579-MVApcp8/Metainfo.txt
# MVA/QID-1581-MVAbankruptcydis/Metainfo.txt
# MVA/QID-1609-MVAdrafthousing/Metainfo.txt
# MVA/QID-1610-MVAdrafthousingt/Metainfo.txt
# MVA/QID-1611-MVApcphousing/Metainfo.txt
# MVA/QID-1612-MVAcorrnorm/Metainfo.txt
# MVA/QID-1614-MVAdescbh/Metainfo.txt
# MVA/QID-1615-MVAlinregbh/Metainfo.txt
# MVA/QID-1616-MVAregbank/Metainfo.txt
# MVA/QID-1617-MVAregpull/Metainfo.txt
# MVA/QID-1618-MVAregzoom/Metainfo.txt
# MVA/QID-1620-MVAscapull1/Metainfo.txt
# MVA/QID-1621-MVAscacar/Metainfo.txt
# MVA/QID-1622-MVAscapull2/Metainfo.txt
# MVA/QID-1629-MVAcontnorm/Metainfo.txt
# MVA/QID-1652-MVAcondnorm/Metainfo.txt
# MVA/QID-1653-MVAedfbootstrap/Metainfo.txt
# MVA/QID-1654-MVAedfnormal/Metainfo.txt
# MVA/QID-1659-MVAsimcidif/Metainfo.txt
# MVA/QID-1660-MVAusenergy/Metainfo.txt
# MVA/QID-1661-MVAlrtest/Metainfo.txt
# MVA/QID-1679-MVAdrugLogistic/Metainfo.txt
# MVA/QID-1682-MVAlinreg2bh/Metainfo.txt
# MVA/QID-1683-MVAresponsesurface/Metainfo.txt
# MVA/QID-1684-MVAsimcibh/Metainfo.txt
# MVA/QID-1700-MVAcontbank3/Metainfo.txt
# MVA/QID-1707-MVACARTBan1/Metainfo.txt
# MVA/QID-1708-MVACARTBan2/Metainfo.txt
# MVA/QID-1709-MVACARTGiniTree1/Metainfo.txt
# MVA/QID-1710-MVACARTTwoingTree1/Metainfo.txt
# MVA/QID-1716-MVAdrug3waysTab/Metainfo.txt
# MVA/QID-1736-MVAfacebank10/Metainfo.txt
# MVA/QID-1737-MVAfacebank50/Metainfo.txt
# MVA/QID-1740-MVAkernelfunctions/Metainfo.txt
# MVA/QID-1743-MVAgumbelclayton/Metainfo.txt
# MVA/QID-1744-MVAscalogret/Metainfo.txt
# MVA/QID-1964-MVAsvmOrangePeel/Metainfo.txt
# MVA/QID-1965-MVAsvmSpiral/Metainfo.txt
# MVA/QID-1966-MVAsvmSig100C1/Metainfo.txt
# MVA/QID-1967-MVAsvmSig2C1/Metainfo.txt
# MVA/QID-1968-MVAsvmSig05C200/Metainfo.txt
# MVA/QID-2086-MVAcancarm/Metainfo.txt
# MVA/QID-2154-MVAppexample/Metainfo.txt
# MVA/QID-2159-MVAfactcarm/Metainfo.txt
# MVA/QID-2244-ppsib/Metainfo.txt
# MVA/QID-2298-MVAboxbhd/Metainfo.txt
# MVA/QID-2305-MVAsimdepex/Metainfo.txt
# MVA/QID-2344-MVAaerbh/Metainfo.txt
# MVA/QID-2426-MVAbluepullover/Metainfo.txt
# MVA/QID-2427-MVAboshousing/Metainfo.txt
# MVA/QID-2428-MVAboxbank1/Metainfo.txt
# MVA/QID-2453-MVAandcur/Metainfo.txt
# MVA/QID-2454-MVAaper/Metainfo.txt
# MVA/QID-2455-MVAbankrupt/Metainfo.txt
# MVA/QID-2511-MVAnpcafood/Metainfo.txt
# MVA/QID-2525-MVAgrouplasso/Metainfo.txt
# MVA/QID-2527-MVAlassologit/Metainfo.txt
# MVA/QID-2544-MVAQnetClusKmeansB/Metainfo.txt
# MVA/QID-2545-MVAQnetClusKmeansT/Metainfo.txt
# MVA/QID-2546-MVAcarsim/Metainfo.txt
# MVA/QID-2547-MVAspecclust/Metainfo.txt
# MVA/QID-2548-MVAQnetClusKmeans/Metainfo.txt
# MVA/QID-2554-MVAspecdecomp/Metainfo.txt
# MVA/QID-2555-MVAlassoregress/Metainfo.txt
# MVA/QID-2558-MVAdrugsim/Metainfo.txt
# MVA/QID-2559-MVAclususcrime/Metainfo.txt
# MVA/QID-2963-MVAlassocontour/Metainfo.txt
# MVA/QID-757-MVAcarrankings/Metainfo.txt
# MVA/QID-904-MVAppsib/Metainfo.txt
# MVA/QID-928-MVAdisfbank/Metainfo.txt
# MVA/QID-930-MVAMDScity1/Metainfo.txt
# MVA/QID-931-MVAMDScity2/Metainfo.txt
# MVA/QID-932-MVAMDSnonmstart/Metainfo.txt
# MVA/QID-933-MVAMDSpooladj/Metainfo.txt
# MVA/QID-934-MVAnmdscar1/Metainfo.txt
# MVA/QID-935-MVAnmdscar2/Metainfo.txt
# MVA/QID-936-MVAnmdscar3/Metainfo.txt
# MVA/QID-941-MVAprofil/Metainfo.txt
# MVA/QID-942-MVAdenbank2/Metainfo.txt
# MVA/QID-945-MVApcabank/Metainfo.txt
# MVA/QID-948-MVApcabankr/Metainfo.txt
# MVA/QID-949-MVAnpcausco2i/Metainfo.txt
# MVA/QID-986-MVAnpcatime/Metainfo.txt
# M_MEM/M_MEM_DAT_Seasonal_Factors/Metainfo.txt
# M_MEM/M_MEM_LMEM_Parameter_Dynamics_Figure/Metainfo.txt
# M_MEM/M_MEM_LMEM_Parameter_Dynamics_Results/Metainfo.txt
# MailProcessingTime/MPT_Fast_Text_Visualization_Example/metainfo.txt
# MailProcessingTime/MPT_Model_Benchmark/metainfo.txt
# MediaNews/Countword/metainfo.txt
# MediaNews/NNTA/NNTAplot/Metainfo.txt
# MediaNews/Newssurprise/Metainfo.txt
# MediaNews/Speculationnews/Metainfo.txt
# Ms_Th_Predict_Poll_From_Emotions/Metainfo.txt
# MuPoMo/MuPoMo_bootstrap/Metainfo.txt
# MuPoMo/MuPoMo_data/Metainfo.txt
# MuPoMo/MuPoMo_main_multipop/Metainfo.txt
# MuPoMo/MuPoMo_main_twopop/Metainfo.txt
# MuPoMo/MuPoMo_normalization/Metainfo.txt
# MuPoMo/MuPoMo_optimization/Metainfo.txt
# MuPoMo/MuPoMo_referencecurve/Metainfo.txt
# NAR/NAR/Metainfo.txt
# NIC_class_2015/NIC_FFTAlogrithm/Metainfo.txt
# NIC_class_2015/NIC_FFTComp/Metainfo.txt
# NIC_class_2015/NIC_FFTImageProcessing/Metainfo.txt
# NIC_class_2015/NIC_FFTMAFilter/Metainfo.txt
# NIC_class_2015/NIC_LevyJumpDiffusion/Metainfo.txt
# NIC_class_2015/NIC_LevyPoisson/Metainfo.txt
# NIC_class_2015/NIC_LevyStableProcess/Metainfo.txt
# NNQR/NNQR_CoVaR/metainfo.txt
# NNQR/NNQR_Heat/metainfo.txt
# NNQR/NNQR_Network/metainfo.txt
# NNQR/NNQR_SNRI/Metainfo.txt
# NetworkCASC/CASCportfolio/Metainfo.txt
# NetworkCASC/CASCsimulation/Metainfo.txt
# NextUnicorn/NextUnicorn_AUC/Metainfo.txt
# NextUnicorn/NextUnicorn_ConditionalTree/Metainfo.txt
# NextUnicorn/NextUnicorn_DataCleaning/Metainfo.txt
# NextUnicorn/NextUnicorn_DescriptiveStats/Metainfo.txt
# NextUnicorn/NextUnicorn_ExitDeal/Metainfo.txt
# NextUnicorn/NextUnicorn_LogisticRegression/Metainfo.txt
# NextUnicorn/NextUnicorn_RandomForest/Metainfo.txt
# NextUnicorn/NextUnicorn_RecursivePartitioning/Metainfo.txt
# NextUnicorn/NextUnicorn_Results/Metainfo.txt
# NextUnicorn/NextUnicorn_Scatter/Metainfo.txt
# NextUnicorn/NextUnicorn_Sigmoid/Metainfo.txt
# NextUnicorn/NextUnicorn_XGBoost/Metainfo.txt
# NextUnicorn/NextUnicorn_helperFunctions/Metainfo.txt
# ONSM/Metainfo.txt
# PAM/PAMCocPia/Metainfo.txt
# PAM/PAMinsam/Metainfo.txt
# PAM/PAMoutsam/Metainfo.txt
# PAM/PAMsimCP/Metainfo.txt
# PAM/PAMsimLR/Metainfo.txt
# PCA-SVM/Metainfo.txt
# PCA-in-an-Asymmetric-Norm/PEC_algorithm_princdir/Metainfo.txt
# PCA-in-an-Asymmetric-Norm/PEC_algorithm_topdown/Metainfo.txt
# PCA-in-an-Asymmetric-Norm/PEC_fMRI/Metainfo.txt
# PCA-in-an-Asymmetric-Norm/PEC_growth/Metainfo.txt
# PCA-in-an-Asymmetric-Norm/PEC_temperature/Metainfo.txt
# PGFP/PGFP_Pricing_month/metainfo.txt
# PGFP/PGFP_Pricing_week/metainfo.txt
# PGFP/PGFP_add_Bs_IQR_logit/metainfo.txt
# PP-CPP/Metainfo.txt
# Psychological-diagnostics/HistofCor/Metainfo.txt
# Q-Kolleg/PDF_2_TXT/metainfo.txt
# Q-Kolleg/ScrapeAbstracts/metainfo.txt
# Q-Kolleg/ScrapeArticles/metainfo.txt
# Q-Kolleg/ScrapeJEL/metainfo.txt
# Q-Kolleg/StemJEL/metainfo.txt
# Q-Kolleg/StemTFIDF_Abstracts/metainfo.txt
# Q-Kolleg/StemTFIDF_Articles/metainfo.txt
# Q-Kolleg/Textmining_Abstracts/metainfo.txt
# Q-Kolleg/TopicModelling_Analysis/metainfo.txt
# Q-Kolleg/TopicModelling_Articles/metainfo.txt
# Q-Problems/QID-1145-SFEgph/Metainfo.txt
# Q-Problems/QID-1260-SFESumm/Metainfo.txt
# Q-Problems/QID-1285-SFEresDens/Metainfo.txt
# Q-Problems/QID-1286-SFEstaticCop/Metainfo.txt
# Q-Problems/QID-1330-SFSevt2/Metainfo.txt
# Q-Problems/QID-1331-SFSheavytail/Metainfo.txt
# Q-Problems/QID-1334-SFSmeanExcessFun/Metainfo.txt
# Q-Problems/QID-1335-SFSmsr1/Metainfo.txt
# Q-Problems/QID-1341-SFStailGEV/Metainfo.txt
# Q-Problems/QID-1342-SFStailGPareto/Metainfo.txt
# Q-Problems/QID-1360-SFEVaRcopulaSIM2ptv/Metainfo.txt
# Q-Problems/QID-2143-SPMsplinekernel/Metainfo.txt
# Q-Problems/QID-2280-SFEtailGPareto_pp/Metainfo.txt
# Q-Problems/QID-2281-SFEtailGPareto_qq/Metainfo.txt
# Q-Problems/QID-2456-SFEFreqFilt/Metainfo.txt
# Q-Problems/QID-2457-SFEPer/Metainfo.txt
# Q-Problems/QID-700-stable/Metainfo.txt
# Q3/rgithubQ_yaml/Metainfo.txt
# Q3/rgithubQ_yaml_TM/Metainfo.txt
# Q3D3LSA/LSA_PC_rotation/Metainfo.txt
# Q3D3LSA/LSA_basics/Metainfo.txt
# Q3D3LSA/LSA_basics_hist_box/Metainfo.txt
# Q3D3LSA/LSA_heatmaps_factors/Metainfo.txt
# Q3D3LSA/LSA_heatmaps_sum/Metainfo.txt
# Q3D3LSA/LSA_kernel/Metainfo.txt
# QNN/QNN_Loss/metainfo.txt
# QNN/QNN_QR/metainfo.txt
# QuachSymanzikForsgren/Metainfo.txt
# Quantlet/Metainfo.txt
# Quantlet_Evaluation/Metainfo.txt
# RCVJ_Forecasting/Code/RCVJ_DataOperation/metainfo.txt
# RCVJ_Forecasting/Code/RCVJ_RealizedVolatility/metainfo.txt
# RCVJ_Forecasting/Code/RCVJ_TimeSeriesAnalysis/metainfo.txt
# RCVJ_Forecasting/Plot/metainfo.txt
# RGoogleAnalytics/DownloadsByCountry/Metainfo.txt
# RGoogleAnalytics/QTopSearch/Metainfo.txt
# RGoogleAnalytics/TopDownloads/Metainfo.txt
# RINFIN/Metainfo.txt
# RJMCMC/metainfo.txt
# RVOL/RVOLaccur/Metainfo.txt
# RVOL/RVOLbackt/Metainfo.txt
# RVOL/RVOLharfnn/Metainfo.txt
# ...
# STF/STFruin17/Metainfo.txt
# STF/STFstab01/Metainfo.txt
# STF/STFstab02/Metainfo.txt
# STF/STFstab03/Metainfo.txt
# STF/STFstab04/Metainfo.txt
# STSM/Metainfo.txt
# SVCJ/Metainfo.txt
# SVCJOptionApp/Metainfo.txt
# SVCJ_MC-1/Metainfo.txt
# SVCJ_MC/Metainfo.txt
# SoNIC/SoNIC_AAPL_BTC/metainfo.txt
# SoNIC/SoNIC_AAPL_BTC_stability/metainfo.txt
# SoNIC/SoNIC_simulation_study/metainfo.txt
# Spatial_Functional_PCA/SFPCA_divide_data/Metainfo.txt
# Spatial_Functional_PCA/SFPCA_whole_procedure/Metainfo.txt
# Stable/Stable_LogDensity_Financials/Metainfo.txt
# Stable/Stable_Rescaling/Metainfo.txt
# Stat_fin_markets/SFM_BSbm/Metainfo.txt
# Stat_fin_markets/SFM_BSprices/Metainfo.txt
# Stat_fin_markets/SFM_Backtesting_VaR/Metainfo.txt
# Stat_fin_markets/SFM_Block_maxima_GEV/Metainfo.txt
# Stat_fin_markets/SFM_DW_anomaly/Metainfo.txt
# Stat_fin_markets/SFM_EMH_Tests/Metainfo.txt
# Stat_fin_markets/SFM_ES_Pareto/Metainfo.txt
# Stat_fin_markets/SFM_Est_CIR/Metainfo.txt
# Stat_fin_markets/SFM_Est_Vasicek/Metainfo.txt
# Stat_fin_markets/SFM_Ext_events/Metainfo.txt
# Stat_fin_markets/SFM_Ext_ret/Metainfo.txt
# Stat_fin_markets/SFM_FBMplot/Metainfo.txt
# Stat_fin_markets/SFM_GEV_Distribution/Metainfo.txt
# Stat_fin_markets/SFM_Gen_Pareto/Metainfo.txt
# Stat_fin_markets/SFM_Hurst/Metainfo.txt
# Stat_fin_markets/SFM_Implied_vola/Metainfo.txt
# Stat_fin_markets/SFM_LPPL_BTC/Metainfo.txt
# Stat_fin_markets/SFM_LPPL_CRIX/Metainfo.txt
# Stat_fin_markets/SFM_LogNormal/Metainfo.txt
# Stat_fin_markets/SFM_MND/Metainfo.txt
# Stat_fin_markets/SFM_Metcalfe/Metainfo.txt
# Stat_fin_markets/SFM_Month_effect/Metainfo.txt
# Stat_fin_markets/SFM_Pareto_Tail/Metainfo.txt
# Stat_fin_markets/SFM_Quant_fin/metainfo.txt
# Stat_fin_markets/SFM_Random_walk/Metainfo.txt
# Stat_fin_markets/SFM_Rolling_GARCH/Metainfo.txt
# Stat_fin_markets/SFM_Sim_CIR/Metainfo.txt
# Stat_fin_markets/SFM_Sim_Pareto/Metainfo.txt
# Stat_fin_markets/SFM_Sim_Pareto_like/Metainfo.txt
# Stat_fin_markets/SFM_Week_effect_bitcoin/Metainfo.txt
# Stat_fin_markets/SFM_Wiener_process/Metainfo.txt
# Stat_fin_markets/SFM_Wienerdens/Metainfo.txt
# Stat_fin_markets/SFM_Year_effect_bitcoin/Metainfo.txt
# Stat_fin_markets/SFM_excess_losses/Metainfo.txt
# Stat_fin_markets/SFM_gamma/Metainfo.txt
# Stat_fin_markets/SFM_theta/Metainfo.txt
# Stat_fin_markets/SFM_vanna/Metainfo.txt
# Stat_fin_markets/SFM_vega/Metainfo.txt
# Stochastic_processes/ar1_process/Metainfo.txt
# Stochastic_processes/random_walk/Metainfo.txt
# Stochastic_processes/randomwalk_ar1/Metainfo.txt
# Styleguide-and-FAQ/Metainfo.txt
# TEDAS/TEDAS_VaR_backtests/Metainfo.txt
# TEDAS/TEDAS_dim_frequencies/Metainfo.txt
# TEDAS/TEDAS_gestalts/Metainfo.txt
# TEDAS/TEDAS_hf_acfs/Metainfo.txt
# TEDAS/TEDAS_perform/Metainfo.txt
# TEDAS/TEDAS_strategies2/Metainfo.txt
# TEDAS/TEDAS_strategies_dynamic/Metainfo.txt
# TEDAS_TAU_SPINE/TEDAS_tau_spine_GS/Metainfo.txt
# TEDAS_TAU_SPINE/TEDAS_tau_spine_GS_KDE/Metainfo.txt
# TEDAS_TAU_SPINE/TEDAS_tau_spine_MF/Metainfo.txt
# TENET/TENET_Linear/Metainfo.txt
# TENET/TENET_SIFIs/Metainfo.txt
# TENET/TENET_SIM/Metainfo.txt
# TENET/TENET_VaR_CoVaR/Metainfo.txt
# TENET/TENET_group_network/Metainfo.txt
# TENET/TENET_total_connectedness/Metainfo.txt
# TENET/TENET_total_in_out_groups/Metainfo.txt
# TENET/TENET_total_in_out_individual/Metainfo.txt
# TERES/TERES_ES_Analytical/Metainfo.txt
# TERES/TERES_ExpectileQuantileDiff/Metainfo.txt
# TERES/TERES_ExpectileQuantileDiffMulti/Metainfo.txt
# TERES/TERES_RollingWindow/Metainfo.txt
# TERES/TERES_Standardization/Metainfo.txt
# TXT/TXTBreweries/Metainfo.txt
# TXT/TXTMcDbl/Metainfo.txt
# TXT/TXTMcDlm/Metainfo.txt
# TXT/TXTSimulation/Metainfo.txt
# TXT/TXTSimulationAttention/Metainfo.txt
# TXT/TXTfpblexical/Metainfo.txt
# TXT/TXTfpbsupervised/Metainfo.txt
# TXT/TXTnlp/Metainfo.txt
# TXT/TXTsgd/Metainfo.txt
# Tenure_Satisfaction/Boxplot_Tenure/Metainfo.txt
# Tenure_Satisfaction/Time_Series/Metainfo.txt
# XFG3/XFGCHD_VaR_Joe/Metainfo.txt
# XFG3/XFGCHD_VaR_StuT/Metainfo.txt
# XFG3/XFGCHD_VaR_hacClayton/Metainfo.txt
# XFG3/XFGCHD_VaR_hacFrank/Metainfo.txt
# XFG3/XFGCHD_VaR_hacGumbel/Metainfo.txt
# XFG3/XFGHistWealthD/Metainfo.txt
# XFG3/XFGPowerLawAlpha/Metainfo.txt
# XFG3/XFGPowerLawEst1/Metainfo.txt
# XFG3/XFGPowerLawEst2/Metainfo.txt
# XFG3/XFGPowerLawEst3/Metainfo.txt
# XFG3/XFGPowerLawP/Metainfo.txt
# XFG3/XFGTVP_BetaChange/Metainfo.txt
# XFG3/XFGTVP_FRM/Metainfo.txt
# XFG3/XFGTVP_LambdaSim/Metainfo.txt
# XFG3/XFGTVP_LambdaSysRisk/Metainfo.txt
# XFG3/XFGTVP_LambdaVIX/Metainfo.txt
# XFG3/XFGTWSE100_strategy_fixedESlevel/Metainfo.txt
# XFG3/XFGTabletoLatex/Metainfo.txt
# XFG3/XFGbetatsacf/Metainfo.txt
# XFG3/XFGdtmDirichlet/Metainfo.txt
# XFG3/XFGdtmEvents/Metainfo.txt
# XFG3/XFGdtmMining/Metainfo.txt
# XFG3/XFGdtmMtGox/Metainfo.txt
# XFG3/XFGdtmTemperature/Metainfo.txt
# XFG3/XFGdtmWDistr/Metainfo.txt
# XFG3/XFGdtmpre/Metainfo.txt
# XFG3/XFGdtmres/Metainfo.txt
# XFG3/XFGexp_rtn_ES_2d/Metainfo.txt
# XFG3/XFGexp_rtn_SRM/Metainfo.txt
# XFG3/XFGexp_rtn_SRM_2d/Metainfo.txt
# XFG3/XFGexp_rtn_SRM_2d/XFGexp_rtn_ES_2d/Metainfo.txt
# XFG3/XFGexp_rtn_SRM_2d/XFGexp_rtn_SRM/Metainfo.txt
# XFG3/XFGkernelcom/Metainfo.txt
# XFG3/XFGmvol01/Metainfo.txt
# XFG3/XFGmvol02/Metainfo.txt
# XFG3/XFGmvol03/Metainfo.txt
# XFG3/XFGmvol04/Metainfo.txt
# XFG3/XFGrvtsacf/Metainfo.txt
# XFG3/XFGsignature/Metainfo.txt
# XFG_2019SS/XFG_Copula_VaR/metainfo.txt
# XFG_2019SS/XFG_Cornish_Fisher/metainfo.txt
# XFG_2019SS/XFG_VAR_ES/metainfo.txt
# ZHAW_FX/CarryStrategyFX/Metainfo.txt
# ZHAW_FX/MomentumStrategyFX/Metainfo.txt
# ZHAW_FX/ValueStrategyFX/Metainfo.txt
# awcd/awcd/Metainfo.txt
# big_data_analysis/GoogleCorrelateWords_and_FRMcomparison/Metainfo.txt
# big_data_analysis/TreeModel/Metainfo.txt
# big_data_analysis/Unemployment_Google_vs_Official/Metainfo.txt
# big_data_analysis/Unemploymentrate_jobagency_comparison/Metainfo.txt
# collection_unsorted/Adaptive_Penalized_Macro_Factors/Metainfo.txt
# collection_unsorted/BQPR_betadensity/Metainfo.txt
# electricitypriceforecasting/QRA/Metainfo.txt
# electricitypriceforecasting/forecastCombination/Metainfo.txt
# electricitypriceforecasting/probabilisticForecast/Metainfo.txt
# electricitypriceforecasting/seasonalityAndForecasting/Metainfo.txt
# exgb/Metainfo.txt
# gaplmsbk/Metainfo.txt
# japanesetwitter/JapaneseTwitter/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Adaptive_Estimation_00025/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Adaptive_Estimation_001/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Adaptive_Estimation_005/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Adaptive_Estimation_Length_00025/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Adaptive_Estimation_Length_001/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Adaptive_Estimation_Length_005/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Critical_Values/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Critical_Values_Th1_001/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Critical_Values_Th1_005/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Critical_Values_Th2_001/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Critical_Values_Th2_005/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Critical_Values_Th3_001/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Critical_Values_Th3_005/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Estimation_Rolling_001/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Estimation_Rolling_005/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Index_Returns/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Index_Returns_Description/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Intervals/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Parameter_Dynamics_Quartiles/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Risk_Bound_Results/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Risk_Bound_Th1_001/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Risk_Bound_Th1_005/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Risk_Bound_Th2_001/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Risk_Bound_Th2_005/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Risk_Bound_Th3_001/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Risk_Bound_Th3_005/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Test_Statistics_Th1_001/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Test_Statistics_Th1_005/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Test_Statistics_Th2_001/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Test_Statistics_Th2_005/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Test_Statistics_Th3_001/Metainfo.txt
# lCARE-BTU-HUB/LCARE_Test_Statistics_Th3_005/Metainfo.txt
# lCARE-BTU-HUB/LCARE_a_rsn/Metainfo.txt
# lCARE-BTU-HUB/LCARE_c_Simulation/Metainfo.txt
# mnistDeepLearning/Metainfo.txt
# mvcaviar/Metainfo.txt
# nutrition_changes_south_korea/DABmi/metainfo.txt
# nutrition_changes_south_korea/DASampleWeights/metainfo.txt
# nutrition_changes_south_korea/DATopFoodGroups/metainfo.txt
# nutrition_changes_south_korea/PlotGDPpCapita/metainfo.txt
# nutrition_changes_south_korea/PlotMacronutrientIntake/metainfo.txt
# nutrition_changes_south_korea/SAClusterAnalysis/metainfo.txt
# nutrition_changes_south_korea/SAMacronutrientChanges/metainfo.txt
# nutrition_changes_south_korea/SAPrincipalComponentAnalysis/metainfo.txt
# opp_comp_abalone/metainfo.txt
# plotting/approx/metainfo.txt
# plotting/bootstrap/metainfo.txt
# plotting/plotLMR/metainfo.txt
# plotting/simulationplot/metainfo.txt
# plotting/timeseries/metainfo.txt
# pricing_kernels_and_implied_volatility/epk3VolaIntervalsVDAX/Metainfo.txt
# pricing_kernels_and_implied_volatility/epk3VolaIntervalsVDAX1m/Metainfo.txt
# pricing_kernels_and_implied_volatility/epk3VolaIntervalsVDAX2m/Metainfo.txt
# pricing_kernels_and_implied_volatility/epk3VolaIntervalsVDAX3m/Metainfo.txt
# pricing_kernels_and_implied_volatility/epkLocLinRndLocConstPD/Metainfo.txt
# pricing_kernels_and_implied_volatility/epkLocLinRndLocLinPD/Metainfo.txt
# pricing_kernels_and_implied_volatility/locLinBW/Metainfo.txt
# pricing_kernels_and_implied_volatility/termStructurePK/Metainfo.txt
# q_awc/awc/Metainfo.txt
# quantile_coherency_replication/Metainfo.txt
# ssmmatlab/SSM_CovFac_d/Metainfo.txt
# ssmmatlab/SSM_ReinselMinkMuskrat_d/Metainfo.txt
# ssmmatlab/SSM_TRAMO_SEATSex2_d/Metainfo.txt
# ssmmatlab/SSM_TsayEx23_d/Metainfo.txt
# topic-models/Doc2ASCII_no_punct/Metainfo.txt
# topic-models/Doc2VectorSpace/Metainfo.txt
# topic-models/LDA_DTM/Metainfo.txt
# topic-models/VisualOverfittingExemp/Metainfo.txt
# topic-models/VisualTFIDF/Metainfo.txt
# varuca/VarucaShiny/Metainfo.txt
# varuca/varuca/Metainfo.txt
# vcExp/VCCARE/Metainfo.txt
# Could not load 20 quantlets.

# %%
df.head()
# Out:
#                             Name author_of_last_comm is_debuggable grade  \
# 0  ADM/HermPolyPlot/Metainfo.txt         Lukas Borke          True     A
# 1  AOBDL_code/codes/metainfo.txt           lizzzi111          True     A
# 2     ARR/ARRboxage/Metainfo.txt      mariussterling          True     A
# 3   ARR/ARRboxgscit/Metainfo.txt         Lukas Borke          True     A
# 4      ARR/ARRboxhb/Metainfo.txt         Lukas Borke          True     A
#
#                                             keywords author_of_first_comm
# 0  orthogonal series graphical representation bas...         chenshic.hub
# 1  hate speech Lightgbm neural networks reduction...  Elizaveta Zinovyeva
# 2  five number summary visualization analysis dep...         AlonaZharova
# 3  five number summary visualization analysis dep...         AlonaZharova
# 4  five number summary visualization analysis dep...         AlonaZharova

# %%
# text preprocessing
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(df.keywords.values)
train_X = tokenizer.texts_to_sequences(df.keywords.values, )
train_X = [np.unique(i) for i in train_X]
train_X = pad_sequences(train_X, maxlen=15, padding='post')
#labels = [i.split('/')[1] for i in df.name]
labels = []
for i in df.Name:
    temp = str(i).split('/')
    if len(temp)==3:
        labels.append(temp[1])
    elif len(temp)==2:
        labels.append(temp[0])
    elif len(temp)==4:
        labels.append(temp[2])
    elif len(temp)==5:
        labels.append(' '.join([temp[0],temp[3]]))
    else:
        labels.append(i)

# %%
#Calculating cosine similarity affinity matrix
C = cosine_similarity(train_X)

# %%
# prepare for plotting
pca = PCA(n_components=2)
pca.fit(train_X)
X = pca.transform(train_X)
for i in [1, 2, 3, 5, 7, 9, 10, 30, 100, 200, 500]:
    max_d = i
    spectral_model_cosine = SpectralClustering(n_clusters = max_d, affinity ='precomputed') 
    clusters = spectral_model_cosine.fit_predict(C) 
    plt.figure(figsize=(10, 8))
    plt.scatter(X[:,0], X[:,1], c=clusters, cmap='prism')
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.title(f'Scatter plot with clusters\' amount = {i}')
    filename=f'{IMG_PATH}/sc_images/for_sc_gif/step'+str(i)+'.png'
    plt.savefig(filename, dpi=96, transparent=True)
    plt.gca()

# %%
#Making 10 clusters using spectral clustering as an example
spectral_model_cosine = SpectralClustering(n_clusters = 10, affinity ='precomputed') 
clusters = spectral_model_cosine.fit_predict(C)

# %%
#Adding cluster labels to the datafram
df['cluster'] = clusters

# %%
#Dropping the 'metainfo.txt' from quantlet names to avoid redundancies
df['Name']= df['Name'].str.rstrip('/Metainfo.txt')

#Viewing quantlet names with cluster lables
df[['Name', 'cluster']]

# %%
### Looking at the names if clusters in a single cluster
clusters = df.loc[df.cluster == 8][['Name', 'keywords','cluster']]
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(clusters)

# %%
tsne = TSNE(n_components=2)
tsne.fit(train_X)
X_t = tsne.fit_transform(train_X)

# %%
len(df.keywords)

# %%
for i in [1, 2, 3, 5, 7, 9, 10, 30, 100, 200, 500, len(df.keywords)]:
    max_d = i
    spectral_model_cosine = SpectralClustering(n_clusters = max_d, affinity ='precomputed') 
    clusters = spectral_model_cosine.fit_predict(C) 
    plt.figure(figsize=(10, 8))
    plt.scatter(X_t[:,0], X_t[:,1], c=clusters, cmap='tab10')
    plt.xlabel('Component 1')
    plt.ylabel('Component 2')
    plt.title(f'Scatter plot with clusters\' amount = {i}')
    filename=f'{IMG_PATH}/sc_images/for_sc_gif/TSNE_step'+str(i)+'.png'
    plt.savefig(filename, dpi=96, transparent=True)
    plt.gca()

# %%
reverse_word_map = dict(map(reversed, tokenizer.word_index.items()))

# %%
max_d = 10
cluster_labels = {}  
for i in range(1, max_d+1):
    df_ = pd.DataFrame(columns = ['word', 'count'])
    df_['word'], df_['count'] = np.unique(train_X[clusters==i], return_counts=True)
    df_ = df_.sort_values(by=['count'], ascending=False)
    #print(df.head(20))
    temp = []
    for word in df_.word.values[1:]:
        if word != 0:
            temp.append(reverse_word_map[word])
    cluster_labels[i] = ' '.join(temp)

# %%
cluster_labels

# %%
max_d=10
spectral_model_cosine = SpectralClustering(n_clusters = max_d, affinity ='precomputed') 
clusters = spectral_model_cosine.fit_predict(C) 
plt.figure(figsize=(20, 16))
for i in range(1, max_d+1):
    df_ = pd.DataFrame(columns = ['word', 'count'])
    df_['word'], df_['count'] = np.unique(train_X[clusters==i], return_counts=True)
    df_ = df_.sort_values(by=['count'], ascending=False)
    #print(df.head(20))
    temp = []
    for word in df_.word.values[1:10]:
        if word != 0:
            temp.append(reverse_word_map[word])
    cluster_labels[i] = ' '.join(temp)       
    plt.scatter(X_t[clusters==i,0], X_t[clusters==i,1], label = cluster_labels[i])
#plt.legend(loc = 'upper left', prop={'size': 10})
plt.legend(loc='upper center', bbox_to_anchor=(1.3, 0.8), prop={'size': 10})
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title(f'Scatter plot with clusters\' amount = {10}')
filename=f'{IMG_PATH}/sc_images/TSNE_10_clusters_label.png'
plt.savefig(filename, dpi=96, transparent=True)
plt.gca()

# %%
max_d=10
spectral_model_cosine = SpectralClustering(n_clusters = max_d, affinity ='precomputed') 
clusters = spectral_model_cosine.fit_predict(C)
plt.figure(figsize=(20, 16))
for i in range(1, max_d+1):
    df_ = pd.DataFrame(columns = ['word', 'count'])
    df_['word'], df_['count'] = np.unique(train_X[clusters==i], return_counts=True)
    df_ = df_.sort_values(by=['count'], ascending=False)
    #print(df.head(20))
    temp = []
    for word in df_.word.values[1:10]:
        if word != 0:
            temp.append(reverse_word_map[word])
    cluster_labels[i] = ' '.join(temp)       
    plt.scatter(X_t[clusters==i,0], X_t[clusters==i,1], label = cluster_labels[i])
#plt.legend(loc = 'upper left', prop={'size': 10})
#plt.legend(loc='upper center', bbox_to_anchor=(1.3, 0.8), prop={'size': 10})
plt.xlabel('Component 1')
plt.ylabel('Component 2')
plt.title(f'Scatter plot with clusters\' amount = {10}')
filename=f'{IMG_PATH}/sc_images/TSNE_10_clusters.png'
plt.savefig(filename, dpi=96, transparent=True)
plt.gca()
